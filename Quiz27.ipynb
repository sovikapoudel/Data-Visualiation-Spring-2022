# %% [markdown]
# <a href="https://colab.research.google.com/github/sovikapoudel/Data-Visualiation-Spring-2022/blob/main/Quiz27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns
import numpy


df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# ##Your Turn
# #Take the first pie chart and create it with the numbers (instead of the percentages) and use a different color scheme that won't have two right next to each other of the same color. Annotate the graph in some way.
# Explain what a Mosaic Plot might be able to show you that a pie and bar chart cannot.

# %%
plt.pie(x=df.groupby('workout_type').workout_type.agg('count'),labels = df.groupby('workout_type').workout_type.agg('count').index, autopct='%.0f%%')
plt.show()

# %%
#to changew color, I will use seaborn color palette
colors = sns.color_palette('bright')[0:12]
plt.pie(x=df.groupby('workout_type').workout_type.agg('count'),labels = df.groupby('workout_type').workout_type.agg('count').index, autopct='%.0f%%', colors=colors)
plt.show()

# %%
#to changew color, I will use seaborn color palette
colors = sns.color_palette('bright')
plt.pie(x=df.groupby('workout_type').workout_type.agg('count'),labels = df.groupby('workout_type').workout_type.agg('count').index, autopct='%.0f%%', colors=colors[1:11]) #this is changing the color using the 1:10 ratio. It is changing the color but not assigning the unique colr. But it still helped to differentiate those two together.
plt.show()

# %%
df1 = df.groupby('workout_type').workout_type.agg(count = 'count')
df1 = df1.reset_index()

df1 #just adding this code here to see the count of workout types
# Out:
#        workout_type  count
# 0           Cricket     93
# 1         Freestyle     96
# 2    Indoor Cycling     80
# 3        Open Water     91
# 4   Outdoor Cycling     85
# 5   Outdoor Running     81
# 6     Pool Swimming     94
# 7         Trail Run     90
# 8         Treadmill     98
# 9          Trekking     94
# 10          Walking     98

# %%
df.groupby('workout_type').workout_type.agg('count').value_counts().plot(kind='pie')
 #I am able to get value by using the value_coulnt() function but not inside of the chart. However I am still not able to figure out how to put value and label both at the same time.

# %%
value=df.groupby('workout_type').workout_type.agg('count').value_counts()

labels = df.groupby('workout_type').workout_type.agg('count').index
fig, ax = plt.subplots(figsize=(10, 25)) #this line of code let me resize the chart
ax.pie(x, labels=labels, colors=colors[2:9]) #this works here as well, using different ratio to see the difference.
plt.legend(labels,loc=1)
ax.set_title("WorkOut Type")
# Out:
# Text(0.5, 1.0, 'WorkOut Type')

# %%
df1 = df.groupby('workout_type').workout_type.agg(count = 'count')
df1 = df1.reset_index()

df1
ax = sns.barplot(data = df1,x = 'workout_type', y = 'count', color = 'blue')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
ax.set_title('One Color Graph')

plt.show()

# %% [markdown]
# ##Explain what a Mosaic Plot might be able to show you that a pie and bar chart cannot.
#
#  - # Mosaic plots are used to show relationships and to provide a visual comparison of groups. It allows to group sizes by scaling in x-axis which is easier to view and compare. Mainly the mosaic plots provide the ability to plot and show the relation between two catergorial value, while in Bar one must be numerical.
# ## Also unlike the barchat, In Mosaic plot boxes lined up in the grid since the are propotional are same.
