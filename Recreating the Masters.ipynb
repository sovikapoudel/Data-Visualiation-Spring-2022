# %% [markdown]
# <a href="https://colab.research.google.com/github/sovikapoudel/Data-Visualiation-Spring-2022/blob/main/Recreating%20the%20Masters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Covid Vaccination Rate by Countries**
# ##Name: Sovika Poudel
# ##ECU ID: 268598
# ##Course ID:  CPMSA 4321, Data Processing and Visualization
# ##Professor: Dr. Nicholas Jacob

# %% [markdown]
# >Abstract: Recreating a Master, Project on Covid-19 vaccination. Covid 19 is still a hot topic and one of the leading cause of death in whole world. It is really hard to predict when it is going to stop or slow down as throughout the years, new varient are always emerging. So, the vaccination is still a important topic to discuss about.
# This Project will demonstrate which part of the world are mostly vaccinated.
# https://covid19.who.int/data
#
# ###The Visualization I am recreating can be found on multiple website. It is in CBC news website and Southeast Asia And Covid-19. Link are attached below respectively.
#
#  https://www.cbc.ca/news/health/canada-vaccine-first-dose-1.6060834
#
#  https://southeastasiacovid.asiasociety.org/southeast-asia-and-covid-19-vaccines-explained/

# %% [markdown]
# <img src = " https://southeastasiacovid.asiasociety.org/wp-content/uploads/2021/06/Coronavirus-vaccine-Single-Dose-chart-World.png">

# %% [markdown]
# ###The download link for the Vaccination data is
# https://covid19.who.int/who-data/vaccination-data.csv

# %% [markdown]
# ##Graphical Excellence
#
# ###This graph would be an example of excellence visualization because with the help of this data and visualization we can get to know how effectively the vaccines are working, where are we in terms of vaccination and so on. This visualization has been presented using a line graph which makes viewer easier to read and analyse the data. There has been used of several colors for diffrent countries for clear understanding. Also, looking at the information provided in the graph, I can tell this has presented the G7 Countries data. I will be focusing on on those countries as well.

# %% [markdown]
# ##Recreating Master

# %% [markdown]
# ##Packages and Dataset
# ###Importing the necessary libraries and loading a dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dfVax= pd.read_csv("https://raw.githubusercontent.com/sovikapoudel/Data-Visualiation-Spring-2022/main/vaccination-data-WHO.csv") #Loading the dataset and storing in pandas dataframe.
dfVax.head(5)
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING    4/27/2022
# 1         Albania  ALB       EURO   REPORTING    4/17/2022
# 2         Algeria  DZA       AFRO   REPORTING    3/23/2022
# 3  American Samoa  ASM       WPRO   REPORTING     4/7/2022
# 4         Andorra  AND       EURO   REPORTING    4/10/2022
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0           5986139.0                      5287027.0
# 1           2827375.0                      1309063.0
# 2                 NaN                      7481277.0
# 3            103065.0                        44175.0
# 4            152301.0                        57850.0
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     15.377                                13.581
# 1                     98.200                                45.997
# 2                        NaN                                17.061
# 3                    186.722                                80.032
# 4                    197.100                                75.942
#
#    PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 0                 4637327.0                           11.912
# 1                 1232442.0                           43.305
# 2                 6147178.0                           14.018
# 3                   40053.0                           72.564
# 4                   53406.0                           70.108
#
#                                        VACCINES_USED FIRST_VACCINE_DATE  \
# 0  Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...          2/22/2021
# 1  AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-V...          1/13/2021
# 2  Beijing CNBG - BBIBP-CorV,Gamaleya - Gam-Covid...          1/30/2021
# 3  Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...         12/21/2020
# 4  AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...          1/20/2021
#
#    NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 0                         4.0                       NaN
# 1                         5.0                  285870.0
# 2                         4.0                  514063.0
# 3                         3.0                   19403.0
# 4                         3.0                   41045.0
#
#    PERSONS_BOOSTER_ADD_DOSE_PER100
# 0                              NaN
# 1                           10.045
# 2                            1.172
# 3                           35.152
# 4                           53.881

# %% [markdown]
# ##Checking Datatypes
# ###Checking the types of data first. It is very important to check and confirm the data types a part of examining Data.

# %%
dfVax.dtypes
# Out:
# COUNTRY                                  object
# ISO3                                     object
# WHO_REGION                               object
# DATA_SOURCE                              object
# DATE_UPDATED                             object
# TOTAL_VACCINATIONS                      float64
# PERSONS_VACCINATED_1PLUS_DOSE           float64
# TOTAL_VACCINATIONS_PER100               float64
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    float64
# PERSONS_FULLY_VACCINATED                float64
# PERSONS_FULLY_VACCINATED_PER100         float64
# VACCINES_USED                            object
# FIRST_VACCINE_DATE                       object
# NUMBER_VACCINES_TYPES_USED              float64
# PERSONS_BOOSTER_ADD_DOSE                float64
# PERSONS_BOOSTER_ADD_DOSE_PER100         float64
# dtype: object

# %% [markdown]
# ### Now, Let see how many countries are there and number of total vaccination by grouping them

# %%
dfVax.COUNTRY.agg('count')
# Out:
# 228

# %% [markdown]
# ###The dateframe aleady grouped by the countries so, I do not need to group them.

# %% [markdown]
# ###There are 228 unique countries in this dataframe. So, lets find out if people are vaccinated or not.
#
# ###First, there are some missing datas (NaN) as this is a timely data so I am filtering out and removing all the NaN so let's drop those tables.

# %%
df2=dfVax.dropna() #just a simple dropna() function removes all the null tables in the dataframe
df2
# Out:
#                                 COUNTRY ISO3 WHO_REGION DATA_SOURCE  \
# 1                               Albania  ALB       EURO   REPORTING
# 3                        American Samoa  ASM       WPRO   REPORTING
# 4                               Andorra  AND       EURO   REPORTING
# 5                                Angola  AGO       AFRO   REPORTING
# 6                              Anguilla  AIA       AMRO   REPORTING
# ..                                  ...  ...        ...         ...
# 222  Venezuela (Bolivarian Republic of)  VEN       AMRO   REPORTING
# 223                            Viet Nam  VNM       WPRO   REPORTING
# 224                   Wallis and Futuna  WLF       WPRO   REPORTING
# 226                              Zambia  ZMB       AFRO   REPORTING
# 227                            Zimbabwe  ZWE       AFRO   REPORTING
#
#     DATE_UPDATED  TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 1      4/17/2022           2827375.0                      1309063.0
# 3       4/7/2022            103065.0                        44175.0
# 4      4/10/2022            152301.0                        57850.0
# 5       4/1/2022          18756893.0                     11799837.0
# 6      4/15/2022             23126.0                        10622.0
# ..           ...                 ...                            ...
# 222    4/15/2022          37860994.0                     22157232.0
# 223    4/21/2022         211284125.0                     80527138.0
# 224    4/14/2022             16426.0                         6592.0
# 226    3/29/2022           3383947.0                      2919895.0
# 227     4/3/2022           9518765.0                      5513887.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 1                       98.200                                45.997
# 3                      186.722                                80.032
# 4                      197.100                                75.942
# 5                       57.070                                35.903
# 6                      154.153                                70.804
# ..                         ...                                   ...
# 222                    133.145                                77.920
# 223                    217.061                                82.729
# 224                    146.061                                58.616
# 226                     18.407                                15.883
# 227                     64.044                                37.098
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 1                   1232442.0                           43.305
# 3                     40053.0                           72.564
# 4                     53406.0                           70.108
# 5                   6127137.0                           18.643
# 6                      9874.0                           65.818
# ..                        ...                              ...
# 222                14287370.0                           50.244
# 223                77035786.0                           79.142
# 224                    6633.0                           58.981
# 226                 2139138.0                           11.636
# 227                 3558338.0                           23.941
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 1    AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-V...          1/13/2021
# 3    Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...         12/21/2020
# 4    AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...          1/20/2021
# 5                                     SII - Covishield          3/10/2021
# 6    AstraZeneca - Vaxzevria,Pfizer BioNTech - Comi...           2/5/2021
# ..                                                 ...                ...
# 222  Beijing CNBG - BBIBP-CorV,CIGB - CIGB-66,Finla...          2/22/2021
# 223  AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...           3/8/2021
# 224                                 Moderna - Spikevax          3/19/2021
# 226  Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...          4/14/2021
# 227  Beijing CNBG - BBIBP-CorV,Bharat - Covaxin,Gam...          2/18/2021
#
#      NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 1                           5.0                  285870.0
# 3                           3.0                   19403.0
# 4                           3.0                   41045.0
# 5                           1.0                  333230.0
# 6                           2.0                    2630.0
# ..                          ...                       ...
# 222                         6.0                  651502.0
# 223                         6.0                15127284.0
# 224                         1.0                    3201.0
# 226                         3.0                   58881.0
# 227                         4.0                  446540.0
#
#      PERSONS_BOOSTER_ADD_DOSE_PER100
# 1                             10.045
# 3                             35.152
# 4                             53.881
# 5                              1.014
# 6                             17.531
# ..                               ...
# 222                            2.291
# 223                           15.541
# 224                           28.463
# 226                            0.320
# 227                            3.004
#
# [174 rows x 16 columns]

# %% [markdown]
# ###Now we know there are total of 174 unique countries without null entries in the dataframe. So, let find first if all the countries has a vaccination record or not!

# %% [markdown]
# ###As this is a timely data, the dataframe is sorted by date so Let's find the maximum number of vaccination by each country and which vaccine were used

# %%
df3 = df2.loc[df2['TOTAL_VACCINATIONS']>0,['DATE_UPDATED','COUNTRY', 'TOTAL_VACCINATIONS', 'VACCINES_USED']] # giving a condition where the number of people vaccination is greater than 0.
df3
# Out:
#     DATE_UPDATED                             COUNTRY  TOTAL_VACCINATIONS  \
# 1      4/17/2022                             Albania           2827375.0
# 3       4/7/2022                      American Samoa            103065.0
# 4      4/10/2022                             Andorra            152301.0
# 5       4/1/2022                              Angola          18756893.0
# 6      4/15/2022                            Anguilla             23126.0
# ..           ...                                 ...                 ...
# 222    4/15/2022  Venezuela (Bolivarian Republic of)          37860994.0
# 223    4/21/2022                            Viet Nam         211284125.0
# 224    4/14/2022                   Wallis and Futuna             16426.0
# 226    3/29/2022                              Zambia           3383947.0
# 227     4/3/2022                            Zimbabwe           9518765.0
#
#                                          VACCINES_USED
# 1    AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-V...
# 3    Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...
# 4    AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...
# 5                                     SII - Covishield
# 6    AstraZeneca - Vaxzevria,Pfizer BioNTech - Comi...
# ..                                                 ...
# 222  Beijing CNBG - BBIBP-CorV,CIGB - CIGB-66,Finla...
# 223  AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...
# 224                                 Moderna - Spikevax
# 226  Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...
# 227  Beijing CNBG - BBIBP-CorV,Bharat - Covaxin,Gam...
#
# [174 rows x 4 columns]

# %% [markdown]
# ###Now we know there are people from every country who are vaccinated but let's find out if they all of them are fully vaccinated or not, By that I mean how many of them have received all the doses.

# %%
highest_vax = df2.loc[df2['PERSONS_FULLY_VACCINATED_PER100']>99,['DATE_UPDATED','COUNTRY', 'PERSONS_FULLY_VACCINATED_PER100']] # giving a condition where the number of people vaccination is greater than 99 which is basically 100. No country are 100% vaccinated so I gave 99% condition.
highest_vax
# Out:
#     DATE_UPDATED  COUNTRY  PERSONS_FULLY_VACCINATED_PER100
# 156     4/7/2022    Palau                           99.082
# 206    4/21/2022  Tokelau                           99.037

# %%
df4 = df2.loc[df2['PERSONS_FULLY_VACCINATED_PER100']<99,['DATE_UPDATED','COUNTRY', 'PERSONS_FULLY_VACCINATED_PER100']]
df4.sort_values(by = "PERSONS_FULLY_VACCINATED_PER100", ascending =False)
# Out:
#     DATE_UPDATED            COUNTRY  PERSONS_FULLY_VACCINATED_PER100
# 31      4/8/2022  Brunei Darussalam                           92.671
# 42     4/15/2022              Chile                           91.160
# 39     4/15/2022     Cayman Islands                           89.350
# 149    3/13/2022               Niue                           87.577
# 23     4/24/2022             Bhutan                           86.871
# ..           ...                ...                              ...
# 181    3/15/2022            Senegal                            6.207
# 37      4/4/2022           Cameroon                            4.527
# 121    3/22/2022         Madagascar                            3.795
# 158    4/19/2022   Papua New Guinea                            2.951
# 43     4/26/2022              China                            0.036
#
# [172 rows x 3 columns]

# %% [markdown]
# ### So, let's find out how many population of United States is vaccinated. My guess is somewhere around 60%

# %%
USA=df2.loc[df2['COUNTRY']=='United States of America',['DATE_UPDATED','COUNTRY', 'PERSONS_FULLY_VACCINATED_PER100']] #Had to look at my csv data to find how US name was recorded!
USA
# Out:
#     DATE_UPDATED                   COUNTRY  PERSONS_FULLY_VACCINATED_PER100
# 218    4/15/2022  United States of America                           64.478

# %% [markdown]
# Now we know, there exists USA so let's sort out the countries and get only required tables.

# %%
dfVax2 = df2.loc[df2['TOTAL_VACCINATIONS']>0,['DATE_UPDATED','COUNTRY', 'TOTAL_VACCINATIONS', 'TOTAL_VACCINATIONS_PER100','PERSONS_FULLY_VACCINATED_PER100']]
G7countries = ['France', 'Canada', 'United States of America', 'Germany', 'Italy', 'Japan', 'United Kingdom']
MyCountries=dfVax2[df2["COUNTRY"].isin(G7countries)]
MyCountries
# Out:
#     DATE_UPDATED                   COUNTRY  TOTAL_VACCINATIONS  \
# 38     4/15/2022                    Canada          81549238.0
# 71     4/17/2022                    France         155393171.0
# 77     4/17/2022                   Germany         172534866.0
# 101    4/17/2022                     Italy         135239316.0
# 103     4/7/2022                     Japan         259734137.0
# 218    4/15/2022  United States of America         552480933.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_FULLY_VACCINATED_PER100
# 38                     216.069                           82.365
# 71                     230.800                           80.208
# 77                     207.500                           76.070
# 101                    226.800                           79.502
# 103                    205.362                           79.726
# 218                    166.911                           64.478

# %% [markdown]
# ##Ploting Graph
#
# ###Looks like US is the last one among all the G7 countries. Now, I have all the required countries so, I am going to create a graph now!I am going to create step by step.

# %%
lineplot1 = MyCountries.plot.line(x='DATE_UPDATED', y='PERSONS_FULLY_VACCINATED_PER100')

# %% [markdown]
# ###I would have to get the raw unrefined data for the graph I wanted to recreate. The dataframe I have is already grouped by country and there is only one date for each country which is updated date. It is available in the same website I referenced on the very begining of project.

# %%
import pandas as pd
G7vax= pd.read_csv("https://raw.githubusercontent.com/sovikapoudel/Data-Visualiation-Spring-2022/main/vax-csv.csv") #Loading the dataset and storing in pandas dataframe.
G7vax.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2/22/2021                 0.0                0.0
# 1  Afghanistan      AFG  2/23/2021                 NaN                NaN
# 2  Afghanistan      AFG  2/24/2021                 NaN                NaN
# 3  Afghanistan      AFG  2/25/2021                 NaN                NaN
# 4  Afghanistan      AFG  2/26/2021                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %% [markdown]
# ##Removing NANs

# %%
G7vax3=G7vax.dropna()
G7vax3
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 94     Afghanistan      AFG  5/27/2021            593313.0           479574.0
# 101    Afghanistan      AFG   6/3/2021            630305.0           481800.0
# 339    Afghanistan      AFG  1/27/2022           5081064.0          4517380.0
# 433        Albania      ALB  2/18/2021              3049.0             2438.0
# 515        Albania      ALB  5/11/2021            622507.0           440921.0
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE  3/25/2022           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE  3/26/2022           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE  3/27/2022           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE  3/28/2022           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE  3/29/2022           9039729.0          5053114.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 94                    113739.0                  2859.0              6487.0
# 101                   148505.0                  4015.0              5285.0
# 339                  3868832.0                  6868.0              9802.0
# 433                      611.0                  1348.0               254.0
# 515                   181586.0                  9548.0             12160.0
# ...                        ...                     ...                 ...
# 86507                3473523.0                139213.0             69579.0
# 86508                3487962.0                100086.0             83429.0
# 86509                3493763.0                 53311.0             90629.0
# 86510                3501493.0                 89321.0            100614.0
# 86511                3510256.0                105369.0            103751.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 94                               1.49                           1.20
# 101                              1.58                           1.21
# 339                             12.76                          11.34
# 433                              0.11                           0.08
# 515                             21.67                          15.35
# ...                               ...                            ...
# 86507                           57.59                          31.90
# 86508                           58.25                          32.38
# 86509                           58.61                          32.59
# 86510                           59.20                          32.97
# 86511                           59.90                          33.48
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 94                                    0.29                           163.0
# 101                                   0.37                           133.0
# 339                                   9.71                           246.0
# 433                                   0.02                            88.0
# 515                                   6.32                          4233.0
# ...                                    ...                             ...
# 86507                                23.02                          4610.0
# 86508                                23.11                          5528.0
# 86509                                23.15                          6005.0
# 86510                                23.20                          6667.0
# 86511                                23.26                          6874.0
#
#                                                 vaccines  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 339    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 433    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 515    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 86507  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86508  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86509  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86510  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86511  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 94     World Health Organization
# 101    World Health Organization
# 339    World Health Organization
# 433           Ministry of Health
# 515           Ministry of Health
# ...                          ...
# 86507         Ministry of Health
# 86508         Ministry of Health
# 86509         Ministry of Health
# 86510         Ministry of Health
# 86511         Ministry of Health
#
#                                           source_website
# 94                              https://covid19.who.int/
# 101                             https://covid19.who.int/
# 339                             https://covid19.who.int/
# 433    https://shendetesia.gov.al/vaksinimi-anticovid...
# 515    https://shendetesia.gov.al/vaksinimi-anticovid...
# ...                                                  ...
# 86507  https://www.arcgis.com/home/webmap/viewer.html...
# 86508  https://www.arcgis.com/home/webmap/viewer.html...
# 86509  https://www.arcgis.com/home/webmap/viewer.html...
# 86510  https://www.arcgis.com/home/webmap/viewer.html...
# 86511  https://www.arcgis.com/home/webmap/viewer.html...
#
# [30847 rows x 15 columns]

# %%
G7Vax2 = G7vax3.loc[G7vax3['total_vaccinations']>0,['date','country', 'people_fully_vaccinated_per_hundred', 'total_vaccinations_per_hundred','people_vaccinated_per_hundred']]
G7list = ['France', 'Canada', 'United States of America', 'Germany', 'Italy', 'Japan', 'United Kingdom']
G7df=G7vax3[G7vax3["country"].isin(G7list)]
G7df
# Out:
#               country iso_code        date  total_vaccinations  \
# 13411          Canada      CAN  12/22/2020             26862.0
# 13412          Canada      CAN  12/23/2020             35547.0
# 13413          Canada      CAN  12/24/2020             45745.0
# 13414          Canada      CAN  12/25/2020             48792.0
# 13415          Canada      CAN  12/26/2020             48808.0
# ...               ...      ...         ...                 ...
# 82355  United Kingdom      GBR   3/24/2022         140830644.0
# 82356  United Kingdom      GBR   3/25/2022         140867776.0
# 82357  United Kingdom      GBR   3/26/2022         140914631.0
# 82358  United Kingdom      GBR   3/27/2022         140937817.0
# 82359  United Kingdom      GBR   3/28/2022         140968337.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 13411            26861.0                      1.0                  5789.0
# 13412            35546.0                      1.0                  8685.0
# 13413            45744.0                      1.0                 10198.0
# 13414            48791.0                      1.0                  3047.0
# 13415            48807.0                      1.0                    16.0
# ...                  ...                      ...                     ...
# 82355         52759213.0               49352885.0                 33618.0
# 82356         52764899.0               49366211.0                 37132.0
# 82357         52775615.0               49385014.0                 46855.0
# 82358         52783242.0               49393056.0                 23186.0
# 82359         52788065.0               49404026.0                 30520.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 13411              3734.0                            0.07
# 13412              4646.0                            0.09
# 13413              5495.0                            0.12
# 13414              5357.0                            0.13
# 13415              5206.0                            0.13
# ...                   ...                             ...
# 82355             34110.0                          206.48
# 82356             33823.0                          206.53
# 82357             33398.0                          206.60
# 82358             32769.0                          206.63
# 82359             32275.0                          206.68
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 13411                           0.07                                 0.00
# 13412                           0.09                                 0.00
# 13413                           0.12                                 0.00
# 13414                           0.13                                 0.00
# 13415                           0.13                                 0.00
# ...                              ...                                  ...
# 82355                          77.35                                72.36
# 82356                          77.36                                72.38
# 82357                          77.38                                72.40
# 82358                          77.39                                72.42
# 82359                          77.39                                72.43
#
#        daily_vaccinations_per_million  \
# 13411                            98.0
# 13412                           122.0
# 13413                           144.0
# 13414                           141.0
# 13415                           137.0
# ...                               ...
# 82355                           500.0
# 82356                           496.0
# 82357                           490.0
# 82358                           480.0
# 82359                           473.0
#
#                                                 vaccines  \
# 13411  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13412  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13413  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13414  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13415  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# ...                                                  ...
# 82355       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 82356       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 82357       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 82358       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 82359       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                              source_name  \
# 13411  Official data from provinces via covid19tracke...
# 13412  Official data from provinces via covid19tracke...
# 13413  Official data from provinces via covid19tracke...
# 13414  Official data from provinces via covid19tracke...
# 13415  Official data from provinces via covid19tracke...
# ...                                                  ...
# 82355                   Government of the United Kingdom
# 82356                   Government of the United Kingdom
# 82357                   Government of the United Kingdom
# 82358                   Government of the United Kingdom
# 82359                   Government of the United Kingdom
#
#                                           source_website
# 13411  https://covid19tracker.ca/vaccinationtracker.html
# 13412  https://covid19tracker.ca/vaccinationtracker.html
# 13413  https://covid19tracker.ca/vaccinationtracker.html
# 13414  https://covid19tracker.ca/vaccinationtracker.html
# 13415  https://covid19tracker.ca/vaccinationtracker.html
# ...                                                  ...
# 82355  https://coronavirus.data.gov.uk/details/vaccin...
# 82356  https://coronavirus.data.gov.uk/details/vaccin...
# 82357  https://coronavirus.data.gov.uk/details/vaccin...
# 82358  https://coronavirus.data.gov.uk/details/vaccin...
# 82359  https://coronavirus.data.gov.uk/details/vaccin...
#
# [2472 rows x 15 columns]

# %% [markdown]
# ###Now, I have cleaned all the NaN values and refined only G7 countries. In this dataframe there are multiple ddate and mutiple entries for same country. Now, let's clean again and create a visualization.

# %% [markdown]
# ###Recreating Master Graph

# %%
fig, ax = plt.subplots()
sns.lineplot(x = 'date', y = 'people_fully_vaccinated_per_hundred', hue = 'country', data = G7df, ax = ax)
ax.set_title("G7 Countries Vaccination ")
ax.legend(title ="Countries")
ax.set_xlabel('Date of vaccination')
ax.set_ylabel("Percentage of vaccination per 100 people")
# Out:
# Text(0, 0.5, 'Percentage of vaccination per 100 people')

# %% [markdown]
# ###Now I am almost close to the master. And, recreating master could include some changes so that it's easier for viewer to visualize so I am going to make following changes to improve in the master
#
# *   The date in the dataframe is not in in panda dataframe so now, it needs to be changed first in order to show the date in one of the axis.
# *   The lines are small which is not eay to ready so changing the line width will be more helpful.
# * Some changes in legend will make graph easier to follow. Like the size and place.

# %%
G7df['date'] = pd.to_datetime(G7df['date'], format="%m/%d/%Y") #here I am changing the dateformat to panda date format
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize = (20,9))
sns.lineplot(x = 'date', y = 'people_fully_vaccinated_per_hundred', hue = 'country', data = G7df, linewidth = 4) #setting the linewidth for better visualization
ax.set_title("G7 Countries Vaccination ")
ax.set_xlabel('Date of vaccination')
ax.set_ylabel("Percentage of vaccination per 100 people")
#adding some changes to legend
ax.legend(title ="Countries", loc = "upper left", prop = {"size":17}) #this is for the legend

# %% [markdown]
# ###This is my final solution for recreating the master. I have spent days on it. It was not easy as it looks. As this is my final project, I have not included 100s of error to make this look clean. Even a simple line would throw an error and would take hours to fix it. Also, internet won't be any help if one doesnot have a good understanding and knowledge of data visualization and the syntax in python. Thanks to all the material provided in my class. I was so overwhelmed until the end but now this project has been an amazing experience. And this course was worth learning.
# ### Thank you Dr. Jacob for offering this Course.

# %% [markdown]
# Honestly, I took alot of reference for this project, It was not possible without these reference below:
#
# Firstly, Dr. Jacob - https://nurfnick.github.io/Data_Viz/Content/Project_Examples/RecreatingMasters.html
#
# This one has guide for almost everything. https://pandas.pydata.org/docs/index.html
#
# Others:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html
# https://www.kaggle.com/code/subhamdutta42/covid-19-vaccination-progress
# https://www.geeksforgeeks.org/matplotlib-pyplot-legend-in-python/#:~:text=A%20legend%20is%20an%20area,best%E2%80%9D%20(upper%20left).
# https://www.kaggle.com/code/raulalmuzara/covid-19-ranking-of-vaccinations-and-vaccines-used
