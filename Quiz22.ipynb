# %% [markdown]
# <a href="https://colab.research.google.com/github/sovikapoudel/Data-Visualiation-Spring-2022/blob/main/Quiz22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Crypto Tracker https://symposium.foragerone.com/okrd22/presentations/37197

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###The first one I would like to examine is the presentation presentated by Jacob Mott , Rad Alrifai from North Eastern University. I find this data very interesting and visually appealing. It has presented the good amount of details in the graphs and images used. The main part I was interested is how it managed to use the data normalization form in the second image from right as Data Normalization is a process of organizing data in well-structured. Using such process is very helpful to eliminate data redundency and ensures that data contains all the record from the selected database. The table above has been presented in 2nd Normalization Form.
#
#
# ###In the first one they have used the case diagram which clearlly presents the relation between the servers and the client. This website is not only showing the updates and price but analysing this case diagram, they are also storing the website visitors and user's data and adding them to their subscriber list.
#
#
# ###However, I am not quiet impressed by the line graph as the price shown on the y-axis does not have any significant meaning as per the presentation. Also, It's pretty confusing to analyse when Cardano ADA and Bitcoin price are set at same range while in reality they differs in thousands

# %% [markdown]
# ---

# %% [markdown]
# ##2. Tulsa Community College - https://symposium.foragerone.com/okrd22/presentations/37513

# %% [markdown]
# ![Soil Bacteria](http://drive.google.com/uc?export=view&id=1iRXjTjG_cXwY-eNTpSa9sLt4-WIpWPRK)

# %% [markdown]
# ![barchart](http://drive.google.com/uc?export=view&id=1LT4UJLxeOCLafS02O3LA2cJo2x1OTCVV)

# %% [markdown]
# ###The overall visualization for the presentation ois quite impressive however in one of the bar graph they have used the odd axis level which starts with 72. If we only look at the size of the bar and compare them it would lead to very misleading result. For example: if percentage total of R2A is shown to be 84 then if we compare the AC with R2A then it should be around the half of the R2A which is clearly not the case they are trying to present.
# ###Besides this one every other graph are accurately labled and used correct level on both axises.

# %% [markdown]
# ---

# %% [markdown]
# # 3. Southwestern Oklahoma State Graduate Business Programs -  https://symposium.foragerone.com/okrd22/presentations/37615

# %% [markdown]
# ![Southwestern Oklahoma State Graduate Business Programs](http://drive.google.com/uc?export=view&id=1IHTLK-KlrDLlUlUI8ZxAdHOWBHmoJU8G)

# %% [markdown]
# ###The next one I am going to review is the presentation by Southwestern Oklahoma State Graduate Business Program. The data they presented is clear and easy to understand however there's no uniformity through out the text and font styles. No consistancy in the fontsize and paragraph spacing they used through out the flyer. Personally, I found the poorly organized bullet points very disappointing. There's seems a lack of organization of data and also the lack the use of data visualization tools and graphics.
#
# ###They could have used a simple bar diagram to show their progress and pie chart to show their alumni record. Showing the actual data and good result could have been a plus point for them to get people's attention.
