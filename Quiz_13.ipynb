# %% [markdown]
# <a href="https://colab.research.google.com/github/sovikapoudel/Data-Visualiation-Spring-2022/blob/main/Quiz_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Name: Sovika Poudel
# ###Course: CMPSA 4313
# ###Student Number: 268598

# %% [markdown]
# What is the data type of the first column? Should you change it or is that the best data type.
#
#
#
# Could any of the columns have been a boolean?
# Name one more interesting fact about this dataset and the datatypes.

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/bank.csv')

df.head(20)
# Out:
#     age            job  marital  education  ... pdays  previous poutcome    y
# 0    30     unemployed  married    primary  ...    -1         0  unknown   no
# 1    33       services  married  secondary  ...   339         4  failure   no
# 2    35     management   single   tertiary  ...   330         1  failure   no
# 3    30     management  married   tertiary  ...    -1         0  unknown   no
# 4    59    blue-collar  married  secondary  ...    -1         0  unknown   no
# 5    35     management   single   tertiary  ...   176         3  failure   no
# 6    36  self-employed  married   tertiary  ...   330         2    other   no
# 7    39     technician  married  secondary  ...    -1         0  unknown   no
# 8    41   entrepreneur  married   tertiary  ...    -1         0  unknown   no
# 9    43       services  married    primary  ...   147         2  failure   no
# 10   39       services  married  secondary  ...    -1         0  unknown   no
# ...

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ###What is the data type of the first column? Should you change it or is that the best data type.
#
# - The first coulmn most of the datatype are string.
# In my opinion, for the data we are trying to retrive it is the correct datatype. For example, if we want to change the datatype from string to number the we might end up having too many numbers and that might be confusing to read especially when the data doesnot follow any order.

# %% [markdown]
# ###2. The second column is job could you assign an order to this string? Could you assign an order the the fourth column education. If yes, what order would you assign?

# %%
import pandas as pd
cols_list= ["age",	"job",	"marital",	"education"	,"default",	"balance","housing", "loan",	"contact",	"day","	month",	"duration",	"campaign",	"pdays",	"previous",	"poutcome",	"y"]
print(df["job"])
# Out:
# 0          unemployed
# 1            services
# 2          management
# 3          management
# 4         blue-collar
#             ...
# 4516         services
# 4517    self-employed
# 4518       technician
# 4519      blue-collar
# 4520     entrepreneur
# Name: job, Length: 4521, dtype: object

# %% [markdown]
# ###Ans:
# - For the job looking at the data, I would not assign it to order as the job roles varies from department to department and there is not exact sequence following the job role. It comes with the education and experience background. So I would not assign any order to it.

# %%
import pandas as pd
cols_list= ["age",	"job",	"marital",	"education"	,"default",	"balance","housing", "loan",	"contact",	"day","	month",	"duration",	"campaign",	"pdays",	"previous",	"poutcome",	"y"]
print(df["education"])
# Out:
# 0         primary
# 1       secondary
# 2        tertiary
# 3        tertiary
# 4       secondary
#           ...
# 4516    secondary
# 4517     tertiary
# 4518    secondary
# 4519    secondary
# 4520     tertiary
# Name: education, Length: 4521, dtype: object

# %% [markdown]
# Education order?
# - Yes, for education I wouuld assign the order as one can only achieve one level of education after completing another level. For example, you can only go for secondary level once you complete the primary. so the order goes like:
# primary>secondary>tertiary so I would assign the Ordinal variables order.

# %% [markdown]
# ###3 Could any of the columns have been a boolean? Name one more interesting fact about this dataset and the datatypes.

# %%
import pandas as pd
cols_list= ["age",	"job",	"marital",	"education"	,"default",	"balance","housing", "loan",	"contact",	"day","	month",	"duration",	"campaign",	"pdays",	"previous",	"poutcome",	"y"]
print(df["education", "loan", "default", "y"])##I thought it would work even for multiple column but throwing an error about not being callable.

# %% [markdown]
# Yes, "education", "loan", "default", "y" have been Boolean.
#
# Interesting fact:
#
# - The datatypes Boolean only gives 2 values. That is either true or False and indicated using 1 and 0.
#
# - There's just 1 married tertiary who is age of 30.
# And I did it by using the filter option in the note book ![image.png](data:image/png;base64,...)
